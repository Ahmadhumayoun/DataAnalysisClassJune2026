# %%
from selenium import webdriver as wd
from selenium.webdriver.common.by import By 
import time as t


driver = wd.Chrome()
driver.get("https://duramolab.com/")
signInButtonFromHomePage = "/html/body/section[1]/div/div/a[2]"
emailField = "/html/body/div/[6]/div/form/div[1]/input"
passField = "/html/body/div[6]/div/form/div[2]/input"
SignInButtonInsideSigninPage= "/html/body/div[6]/div/form/button"

t.sleep(3)
driver.find_element(By.XPATH,signInButtonFromHomePage).click()
t.sleep(3)
driver.find_element(By.XPATH,emailField).send_keys("ahmadonfiver@gmail.com")
driver.find_element(By.XPATH,passField).send_keys("/////")
t.sleep(1)
driver.find_element(By.XPATH,SignInButtonInsideSigninPage).click()
t.sleep(30)
driver.quit
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[13], line 14
#      11 SignInButtonInsideSigninPage= "/html/body/div[6]/div/form/button"
#      13 t.sleep(3)
# ---> 14 driver.find_element(By.XPATH,signInButtonFromHomePage).click()
#      15 t.sleep(3)
#      16 driver.find_element(By.XPATH,emailField).send_keys("ahmadonfiver@gmail.com")
#
# File ~/Documents/GitHubProjects/DataAnalysisClassJune2026/.venv/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:926, in WebDriver.find_element(self, by, value)
#     923         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     924     return elements[0]
# --> 926 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# ...

# %%
from selenium import webdriver as wd
from selenium.webdriver.common.by import By 
import time as t
from selenium.webdriver.support.ui import WebDriverWait
waituntil = WebDriverWait(driver, 10)
driver = wd.Chrome()
driver.get("https://www.pinterest.com/")
mailXpath = "#streamlined-login-email"
t.sleep(3)
waituntil.until(lambda driver: driver.find_element(By.CSS_SELECTOR,mailXpath))
driver.find_element(By.CSS_SELECTOR,mailXpath).send_keys("Ahmad")

# %%
import undetected_chromedriver as uc
from selenium.webdriver.common.by import By
import time as t

driver = uc.Chrome(version_main=150)
driver.get("https://orteil.dashnet.org/cookieclicker/")
t.sleep(10)

englishButton = "/html/body/div[2]/div[2]/div[12]/div/div[1]/div[1]/div[2]"
try:
    driver.find_element(By.XPATH, englishButton).click()
except:
    pass
t.sleep(10)

cookie = "//div[@id='bigCookie']"

upgrades = []
for i in range(2, 22):
    upgrades.append("//div[@id='upgrades']/div[" + str(i) + "]")

while True:
    try:
        driver.find_element(By.XPATH, cookie).click()
        for u in upgrades:
            try:
                driver.find_element(By.XPATH, u).click()
            except:
                pass
        for p in driver.find_elements(By.XPATH, "//div[contains(@class,'product') and contains(@class,'enabled')]"):
            p.click()
    except:
        pass
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[4], line 23
#      20     upgrades.append("/html/body/div[1]/div[2]/div[19]/div[3]/div[6]/div[" + str(i) + "]")
#      22 while True:
# ---> 23     driver.find_element(By.XPATH, cookie).click()
#      24     for u in upgrades:
#      25         try:
#
# File ~/Documents/GitHubProjects/DataAnalysisClassJune2026/.venv/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:926, in WebDriver.find_element(self, by, value)
#     923         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     924     return elements[0]
# --> 926 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# ...
