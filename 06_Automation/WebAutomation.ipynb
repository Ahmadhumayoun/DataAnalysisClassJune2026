# %%
from selenium import webdriver as wd
from selenium.webdriver.common.by import By 
import time as t


driver = wd.Chrome()
driver.get("https://duramolab.com/")
signInButtonFromHomePage = "/html/body/section[1]/div/div/a[2]"
emailField = "/html/body/div/[6]/div/form/div[1]/input"
passField = "/html/body/div[6]/div/form/div[2]/input"
SignInButtonInsideSigninPage= "/html/body/div[6]/div/form/button"

t.sleep(3)
driver.find_element(By.XPATH,signInButtonFromHomePage).click()
t.sleep(3)
driver.find_element(By.XPATH,emailField).send_keys("ahmadonfiver@gmail.com")
driver.find_element(By.XPATH,passField).send_keys("/////")
t.sleep(1)
driver.find_element(By.XPATH,SignInButtonInsideSigninPage).click()
t.sleep(30)
driver.quit
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[13], line 14
#      11 SignInButtonInsideSigninPage= "/html/body/div[6]/div/form/button"
#      13 t.sleep(3)
# ---> 14 driver.find_element(By.XPATH,signInButtonFromHomePage).click()
#      15 t.sleep(3)
#      16 driver.find_element(By.XPATH,emailField).send_keys("ahmadonfiver@gmail.com")
#
# File ~/Documents/GitHubProjects/DataAnalysisClassJune2026/.venv/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:926, in WebDriver.find_element(self, by, value)
#     923         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     924     return elements[0]
# --> 926 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/Documents/GitHubProjects/DataAnalysisClassJune2026/.venv/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File ~/Documents/GitHubProjects/DataAnalysisClassJune2026/.venv/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=150.0.7871.187)
# Stacktrace:
# 0   chromedriver                        0x0000000100a3f6fc chromedriver + 5945084
# 1   chromedriver                        0x00000001004e04e8 chromedriver + 312552
# 2   chromedriver                        0x00000001004b9b70 chromedriver + 154480
# 3   chromedriver                        0x0000000100551d34 chromedriver + 777524
# 4   chromedriver                        0x00000001005687c4 chromedriver + 870340
# 5   chromedriver                        0x000000010051f33c chromedriver + 570172
# 6   chromedriver                        0x0000000100a04a04 chromedriver + 5704196
# 7   chromedriver                        0x0000000100a08284 chromedriver + 5718660
# 8   chromedriver                        0x00000001009ea880 chromedriver + 5597312
# 9   chromedriver                        0x0000000100a08b18 chromedriver + 5720856
# 10  chromedriver                        0x00000001009db9f8 chromedriver + 5536248
# 11  chromedriver                        0x0000000100a2d40c chromedriver + 5870604
# 12  chromedriver                        0x0000000100a2d56c chromedriver + 5870956
# 13  chromedriver                        0x0000000100a3f354 chromedriver + 5944148
# 14  libsystem_pthread.dylib             0x0000000185d11c54 _pthread_start + 132
# 15  libsystem_pthread.dylib             0x0000000185d0cc18 thread_start + 4

# %%
from selenium import webdriver as wd
from selenium.webdriver.common.by import By 
import time as t

driver = wd.Chrome()
driver.get("https://www.pinterest.com/")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 5
#       2 from selenium.webdriver.common.by import By
#       3 import time as t
# ----> 5 driver = wd.Chrome()
#       6 driver.get("https://www.pinterest.com/")
#
# File ~/Documents/GitHubProjects/DataAnalysisClassJune2026/.venv/lib/python3.9/site-packages/selenium/webdriver/chrome/webdriver.py:46, in WebDriver.__init__(self, options, service, keep_alive)
#      43 service = service if service else Service()
#      44 options = options if options else Options()
# ---> 46 super().__init__(
#      47     browser_name=DesiredCapabilities.CHROME["browserName"],
#      48     vendor_prefix="goog",
#      49     options=options,
#      50     service=service,
#      51     keep_alive=keep_alive,
#      52 )
#
# File ~/Documents/GitHubProjects/DataAnalysisClassJune2026/.venv/lib/python3.9/site-packages/selenium/webdriver/chromium/webdriver.py:55, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      52 options = options if options else ChromiumOptions()
#      54 finder = DriverFinder(self.service, options)
# ---> 55 if finder.get_browser_path():
#      56     options.binary_location = finder.get_browser_path()
#      57     options.browser_version = None
#
# File ~/Documents/GitHubProjects/DataAnalysisClassJune2026/.venv/lib/python3.9/site-packages/selenium/webdriver/common/driver_finder.py:47, in DriverFinder.get_browser_path(self)
#      46 def get_browser_path(self) -> str:
# ---> 47     return self._binary_paths()["browser_path"]
#
# File ~/Documents/GitHubProjects/DataAnalysisClassJune2026/.venv/lib/python3.9/site-packages/selenium/webdriver/common/driver_finder.py:67, in DriverFinder._binary_paths(self)
#      65     self._paths["driver_path"] = path
#      66 else:
# ---> 67     output = SeleniumManager().binary_paths(self._to_args())
#      68     if Path(output["driver_path"]).is_file():
#      69         self._paths["driver_path"] = output["driver_path"]
#
# File ~/Documents/GitHubProjects/DataAnalysisClassJune2026/.venv/lib/python3.9/site-packages/selenium/webdriver/common/selenium_manager.py:54, in SeleniumManager.binary_paths(self, args)
#      51 args.append("--output")
#      52 args.append("json")
# ---> 54 return self._run(args)
#
# File ~/Documents/GitHubProjects/DataAnalysisClassJune2026/.venv/lib/python3.9/site-packages/selenium/webdriver/common/selenium_manager.py:118, in SeleniumManager._run(args)
#     116     completed_proc = subprocess.run(args, capture_output=True, creationflags=subprocess.CREATE_NO_WINDOW)
#     117 else:
# --> 118     completed_proc = subprocess.run(args, capture_output=True)
#     119 stdout = completed_proc.stdout.decode("utf-8").rstrip("\n")
#     120 stderr = completed_proc.stderr.decode("utf-8").rstrip("\n")
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/subprocess.py:507, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     505 with Popen(*popenargs, **kwargs) as process:
#     506     try:
# --> 507         stdout, stderr = process.communicate(input, timeout=timeout)
#     508     except TimeoutExpired as exc:
#     509         process.kill()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/subprocess.py:1134, in Popen.communicate(self, input, timeout)
#    1131     endtime = None
#    1133 try:
# -> 1134     stdout, stderr = self._communicate(input, endtime, timeout)
#    1135 except KeyboardInterrupt:
#    1136     # https://bugs.python.org/issue25942
#    1137     # See the detailed comment in .wait().
#    1138     if timeout is not None:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/subprocess.py:1979, in Popen._communicate(self, input, endtime, orig_timeout)
#    1972     self._check_timeout(endtime, orig_timeout,
#    1973                         stdout, stderr,
#    1974                         skip_check_and_raise=True)
#    1975     raise RuntimeError(  # Impossible :)
#    1976         '_check_timeout(..., skip_check_and_raise=True) '
#    1977         'failed to raise TimeoutExpired.')
# -> 1979 ready = selector.select(timeout)
#    1980 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1982 # XXX Rewrite these to use non-blocking I/O on the file
#    1983 # objects; they are no longer using C stdio!
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:
